# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data[data['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
tes = data[data['Survived'] == 1]
a = tes.groupby('Pclass').agg(jumlah = ('Survived','sum'))
a
# Out:
#         jumlah
# Pclass
# 1          136
# 2           87
# 3          119

# %%
uslmt = data[data['Survived'] == 1]
utslmt = data[data['Survived'] == 0]

# %%
uslmt.head(1)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
psns = pd.pivot_table(data, index = ['Survived'],
                    values = ['Age'],
                    aggfunc={'Age':'mean'})
psns
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
data.loc[ (data.Age < 25), 'age_interval' ] = '25'
data.loc[ (data.Age > 25) & (data.Age < 36), 'age_interval' ] = '25-35'
data.loc[ (data.Age > 35) & (data.Age < 51), 'age_interval' ] = '36-50'
data.loc[ (data.Age > 50), 'age_interval' ] = '> 50'
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked age_interval
# 0      0         A/5 21171   7.2500   NaN        S           25
# 1      0          PC 17599  71.2833   C85        C        36-50
# 2      0  STON/O2. 3101282   7.9250   NaN        S        25-35
# ...

# %%
a = data[data['Survived'] == 1]
a = a.groupby('age_interval').agg(jml = ('Survived','sum'))
a[a.jml == a.jml.max()]
# Out:
#               jml
# age_interval
# 25            118

# %%
a = data[data['Survived'] == 1]
a = a.groupby('age_interval').agg(jml = ('Survived','sum'))
a
# Out:
#               jml
# age_interval
# 25            118
# 25-35          83
# 36-50          61
# > 50           22

# %%
# df.loc[df['Value'].idxmax()]
